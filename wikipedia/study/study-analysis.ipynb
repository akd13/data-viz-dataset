# %%
import pandas as pd

# %%
df = pd.read_json('graph-description-default-rtdb-export.json')

# %%
df_csv['difficulty_rating'] = df_csv['difficulty_rating'].astype(int)

# %%
category_stats = df_csv.groupby('category')['difficulty_rating'].agg(['count', 'mean']).reset_index()
category_stats.columns = ['Category', 'Count', 'Mean Difficulty Rating']

category_stats_sorted = category_stats.sort_values(by='Count', ascending=False)

category_stats_sorted.reset_index(drop=True, inplace=True)

# %%
category_stats_sorted
# Out:
#                                              Category  Count
# 0                             Nutaarmiut / Population     12  \
# 1   History of Georgetown University / Early growt...     12
# 2                         Great Southern Group / Fall      9
# 3                          Bootham Crescent / Records      9
# 4   Anatomy of an Epidemic / Synopsis / Magic bullets      7
# 5                 Cloture / United States / Procedure      7
# 6   European debt crisis / Evolution of the crisis...      4
# 7   Federal political financing in Canada / Privat...      4
# 8                      European debt crisis contagion      3
# 9   Ernie Toshack with the Australian cricket team...      3
# 10                            Nanortalik / Population      2
# 11  Near-infrared window in biological tissue / Ab...      2
# 12  Safety of electronic cigarettes / Fires, explo...      2
# 13                          Single crossing condition      2
# ...

# %%
df_descriptions = df_csv.groupby('category')['descriptions'].agg(list).reset_index()

# %%
for i,row in df_descriptions.iterrows():
    image = row[0]
    descriptions = row[1]
    print(row[0])
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    for d in descriptions:
        print(d)
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
# Out:
# Anatomy of an Epidemic / Synopsis / Magic bullets
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ['It is a bar graph showing evaluation of people and mental illness in 1987 when Prozac was introduced vs 2003 when Prozac was readily available']
# ['A bar graph comparing numbers of Americans who received SSDI and SSI in 1987 and 2003']
# ['The number of people receiving benefits for metal illness doubled between 1987 and 2003.']
# ...
